# %%
import pandas as pd
df = pd.read_csv('Credit_card.csv')
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0        -18772.0         365243             1           0      0         0
# 1        -13557.0           -586             1           1      1         0
# 2             NaN           -586             1           1      1         0
# 3        -13557.0           -586             1           1      1         0
# 4        -13557.0           -586             1           1      1         0
#
#   Type_Occupation  Family_Members
# 0             NaN               2
# 1             NaN               2
# 2             NaN               2
# 3             NaN               2
# 4             NaN               2

# %%
df.shape
# Out:
# (1548, 18)

# %%
label = pd.read_csv('Credit_card_label.csv')
label
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
df = df.merge(label, on = 'Ind_ID', how='left')
df
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# 1     Commercial associate               Higher education
# 2     Commercial associate               Higher education
# 3     Commercial associate               Higher education
# 4     Commercial associate               Higher education
# ...                    ...                            ...
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 0                  Married  House / apartment        -18772.0         365243
# 1                  Married  House / apartment        -13557.0           -586
# 2                  Married  House / apartment             NaN           -586
# 3                  Married  House / apartment        -13557.0           -586
# 4                  Married  House / apartment        -13557.0           -586
# ...                    ...                ...             ...            ...
# 1543               Married  House / apartment        -11957.0          -2182
# 1544  Single / not married  House / apartment        -10229.0          -1209
# 1545               Married  House / apartment        -13174.0          -2477
# 1546        Civil marriage  House / apartment        -15292.0           -645
# 1547               Married  House / apartment        -16601.0          -2859
#
#       Mobile_phone  Work_Phone  Phone  EMAIL_ID Type_Occupation  \
# 0                1           0      0         0             NaN
# 1                1           1      1         0             NaN
# 2                1           1      1         0             NaN
# 3                1           1      1         0             NaN
# 4                1           1      1         0             NaN
# ...            ...         ...    ...       ...             ...
# 1543             1           0      0         0        Managers
# 1544             1           0      0         0     Accountants
# 1545             1           0      0         0        Managers
# 1546             1           1      1         0         Drivers
# 1547             1           0      0         0             NaN
#
#       Family_Members  label
# 0                  2      1
# 1                  2      1
# 2                  2      1
# 3                  2      1
# 4                  2      1
# ...              ...    ...
# 1543               2      0
# 1544               1      0
# 1545               4      0
# 1546               2      0
# 1547               2      0
#
# [1548 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
#  17  Family_Members   1548 non-null   int64
#  18  label            1548 non-null   int64
# dtypes: float64(2), int64(9), object(8)
# memory usage: 229.9+ KB

# %%
df.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# 25%     -3174.500000           1.0     0.000000     0.000000     0.000000
# 50%     -1565.000000           1.0     0.000000     0.000000     0.000000
# 75%      -431.750000           1.0     0.000000     1.000000     0.000000
# max    365243.000000           1.0     1.000000     1.000000     1.000000
#
#        Family_Members        label
# count     1548.000000  1548.000000
# mean         2.161499     0.113049
# std          0.947772     0.316755
# min          1.000000     0.000000
# 25%          2.000000     0.000000
# 50%          2.000000     0.000000
# 75%          3.000000     0.000000
# max         15.000000     1.000000

# %%
df.isna().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
df.drop(columns=('Type_Occupation'), inplace=True)

# %%
df.shape
# Out:
# (1548, 18)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Ind_ID            0
# GENDER            0
# Car_Owner         0
# Propert_Owner     0
# CHILDREN          0
# Annual_income     0
# Type_Income       0
# EDUCATION         0
# Marital_status    0
# Housing_type      0
# Birthday_count    0
# Employed_days     0
# Mobile_phone      0
# Work_Phone        0
# Phone             0
# EMAIL_ID          0
# Family_Members    0
# label             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
gender_income = df['Annual_income'].groupby(df['GENDER']).mean()
gender_income
# Out:
# GENDER
# F    172391.840021
# M    222485.245902
# Name: Annual_income, dtype: float64

# %%
sns.barplot(x=gender_income.index, y=gender_income.values )
plt.title('Average income by Gender')
plt.show()

# %%
label_counts = df['label'].value_counts()
label_counts
# Out:
# label
# 0    1336
# 1     160
# Name: count, dtype: int64

# %%
plt.pie(label_counts, labels = ['Credit Approved', 'Credit Rejected'], autopct ='%1.1f%%')
plt.show()

# %%
df.groupby('Type_Income')['Annual_income'].mean()
# Out:
# Type_Income
# Commercial associate    233880.169972
# Pensioner               154964.866795
# State servant           210130.434783
# Working                 180154.579974
# Name: Annual_income, dtype: float64

# %%
df.groupby('Marital_status')['Annual_income'].mean()
# Out:
# Marital_status
# Civil marriage          192787.128713
# Married                 189031.624629
# Separated               189964.285714
# Single / not married    209353.211009
# Widow                   158550.000000
# Name: Annual_income, dtype: float64

# %%
df.groupby('Housing_type')['Family_Members'].sum()
# Out:
# Housing_type
# Co-op apartment           5
# House / apartment      2900
# Municipal apartment      92
# Office apartment         21
# Rented apartment         46
# With parents            175
# Name: Family_Members, dtype: int64

# %%
df.groupby('GENDER')['Birthday_count'].min()*-1
# Out:
# GENDER
# F    24946.0
# M    24662.0
# Name: Birthday_count, dtype: float64

# %%
df.groupby('Propert_Owner')['Annual_income'].mean()
# Out:
# Propert_Owner
# N    183343.352601
# Y    194722.899181
# Name: Annual_income, dtype: float64

# %%
sns.boxplot(x='Marital_status', y='Annual_income', data=df)
# Out:
# <Axes: xlabel='Marital_status', ylabel='Annual_income'>

# %%
df.groupby('Marital_status')['Family_Members'].sum().plot(kind='pie', autopct ='%1.1f%%')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df.boxplot(column='Annual_income', by='EDUCATION')
# Out:
# <Axes: title={'center': 'Annual_income'}, xlabel='EDUCATION'>

# %%
df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Family_Members', 'label'],
#       dtype='object')

# %%
data = df[['GENDER','Car_Owner','Propert_Owner','Annual_income','Marital_status','EDUCATION','label']]
data
# Out:
#      GENDER Car_Owner Propert_Owner  Annual_income        Marital_status  \
# 0         M         Y             Y       180000.0               Married
# 1         F         Y             N       315000.0               Married
# 4         F         Y             N       315000.0               Married
# 6         F         Y             N       315000.0               Married
# 7         F         N             N       180000.0               Married
# ...     ...       ...           ...            ...                   ...
# 1542      M         Y             N       360000.0               Married
# 1544      F         N             N       225000.0  Single / not married
# 1545      M         Y             Y       180000.0               Married
# 1546      M         Y             N       270000.0        Civil marriage
# 1547      F         Y             Y       225000.0               Married
#
#                           EDUCATION  label
# 0                  Higher education      1
# 1                  Higher education      1
# 4                  Higher education      1
# 6                  Higher education      1
# 7     Secondary / secondary special      1
# ...                             ...    ...
# 1542  Secondary / secondary special      0
# 1544              Incomplete higher      0
# 1545               Higher education      0
# 1546  Secondary / secondary special      0
# 1547               Higher education      0
#
# [1496 rows x 7 columns]

# %%
df['EDUCATION'].unique()
# Out:
# array(['Higher education', 'Secondary / secondary special',
#        'Lower secondary', 'Incomplete higher', 'Academic degree'],
#       dtype=object)

# %%
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

# %%
data['Car_Owner'] = labelencoder.fit_transform(data['Car_Owner'])
data['GENDER'] = labelencoder.fit_transform(data['GENDER'])
data['Propert_Owner'] = labelencoder.fit_transform(data['Propert_Owner'])
data['Marital_status'] = labelencoder.fit_transform(data['Marital_status'])
data['EDUCATION'] = labelencoder.fit_transform(data['EDUCATION'])
# Out:
# C:\Users\IMAKA\AppData\Local\Temp\ipykernel_4192\3519534814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Car_Owner'] = labelencoder.fit_transform(data['Car_Owner'])
# C:\Users\IMAKA\AppData\Local\Temp\ipykernel_4192\3519534814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['GENDER'] = labelencoder.fit_transform(data['GENDER'])
# C:\Users\IMAKA\AppData\Local\Temp\ipykernel_4192\3519534814.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Propert_Owner'] = labelencoder.fit_transform(data['Propert_Owner'])
# C:\Users\IMAKA\AppData\Local\Temp\ipykernel_4192\3519534814.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Marital_status'] = labelencoder.fit_transform(data['Marital_status'])
# C:\Users\IMAKA\AppData\Local\Temp\ipykernel_4192\3519534814.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['EDUCATION'] = labelencoder.fit_transform(data['EDUCATION'])

# %%
data
# Out:
#       GENDER  Car_Owner  Propert_Owner  Annual_income  Marital_status  \
# 0          1          1              1       180000.0               1
# 1          0          1              0       315000.0               1
# 4          0          1              0       315000.0               1
# 6          0          1              0       315000.0               1
# 7          0          0              0       180000.0               1
# ...      ...        ...            ...            ...             ...
# 1542       1          1              0       360000.0               1
# 1544       0          0              0       225000.0               3
# 1545       1          1              1       180000.0               1
# 1546       1          1              0       270000.0               0
# 1547       0          1              1       225000.0               1
#
#       EDUCATION  label
# 0             1      1
# 1             1      1
# 4             1      1
# 6             1      1
# 7             4      1
# ...         ...    ...
# 1542          4      0
# 1544          2      0
# 1545          1      0
# 1546          4      0
# 1547          1      0
#
# [1496 rows x 7 columns]

# %%
X = data.drop('label', axis='columns')
X
# Out:
#       GENDER  Car_Owner  Propert_Owner  Annual_income  Marital_status  \
# 0          1          1              1       180000.0               1
# 1          0          1              0       315000.0               1
# 4          0          1              0       315000.0               1
# 6          0          1              0       315000.0               1
# 7          0          0              0       180000.0               1
# ...      ...        ...            ...            ...             ...
# 1542       1          1              0       360000.0               1
# 1544       0          0              0       225000.0               3
# 1545       1          1              1       180000.0               1
# 1546       1          1              0       270000.0               0
# 1547       0          1              1       225000.0               1
#
#       EDUCATION
# 0             1
# 1             1
# 4             1
# 6             1
# 7             4
# ...         ...
# 1542          4
# 1544          2
# 1545          1
# 1546          4
# 1547          1
#
# [1496 rows x 6 columns]

# %%
y =data['label']
y
# Out:
# 0       1
# 1       1
# 4       1
# 6       1
# 7       1
#        ..
# 1542    0
# 1544    0
# 1545    0
# 1546    0
# 1547    0
# Name: label, Length: 1496, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions):
    print('Accuracy score is {}'.format(accuracy_score(y_test, predictions)))

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
scaled_X_train,y_train = sm.fit_resample(scaled_X_train, y_train)

# %%
y_test.unique()
# Out:
# (300,)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(scaled_X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_predictions = log_model.predict(scaled_X_test)

# %%
modelperformance(log_predictions)
# Out:
# Accuracy score is 0.58

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.neighbors import KNeighborsClassifier
param_grid = {'n_neighbors' : [3,5,7,9,11],
               'weights' : ['uniform','distance'],
               'algorithm' : ['auto', 'kd_tree']}

gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv=2)

# %%
gridkn.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'kd_tree'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 11, 'weights': 'distance'}

# %%
knpreds = gridkn.predict(scaled_X_test)

# %%
modelperformance(knpreds)
# Out:
# Accuracy score is 0.69

# %%
from sklearn.svm import SVC
svm = SVC()
param_grid_svr = {"C":[0.01,0.1,0.5,1],
                  'kernel': ['linear', 'rbf','poly']}

gridsvr = GridSearchCV(svm,param_grid_svr)

# %%
gridsvr.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
pred_svc = gridsvr.predict(scaled_X_test)
modelperformance(pred_svc)
# Out:
# Accuracy score is 0.5666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier
param_grid = {
    'criterion' :['gini','entropy'],
    'splitter': ['best','random'],
    'max_depth' : [None, 10,20,30,40,50],
    'min_samples_split': [2,5,10],
    'min_samples_leaf': [1,2,4]
}

grid_search_tree = GridSearchCV(estimator=DecisionTreeClassifier(),param_grid=param_grid)

# %%
grid_search_tree.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
preds = grid_search_tree.predict(scaled_X_test)
modelperformance(preds)
# Out:
# Accuracy score is 0.4033333333333333

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
n_estimators = [32,64,128,256]
max_features = [2,3,4]
bootstrap = [True, False]
oob_score = [True, False]

# %%
param_grid_rfc = {
    'n_estimators': n_estimators,
    'max_features' : max_features,
    'bootstrap' : bootstrap,
    'oob_score': oob_score
}

# %%
grid_rfc = GridSearchCV(rfc,param_grid_rfc)

# %%
grid_rfc.fit(scaled_X_train, y_train)
# Out:
# d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\ensemble\_forest.py", line 448, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.82007125 0.82663522 0.82288705 0.82054403 0.82007455 0.82382382
#  0.8214775  0.82241427 0.82851206 0.82007125 0.82288705 0.82522897
#  0.8271058  0.82288265 0.82522677 0.82522787 0.82944882 0.83179074
#  0.82944663 0.83085508 0.82804037 0.82851206 0.82851316 0.83085508
#         nan 0.82569515        nan 0.82475949        nan 0.82710361
#         nan 0.82569735        nan 0.82991501        nan 0.82757089
#         nan 0.82663192        nan 0.82616574        nan 0.82663632
#         nan 0.82898154        nan 0.82992051        nan 0.82804477]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256],
#                          'oob_score': [True, False]})

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 4, 'n_estimators': 32, 'oob_score': False}

# %%
pred_rfc = grid_rfc.predict(scaled_X_test)
modelperformance(pred_rfc)
# Out:
# Accuracy score is 0.37333333333333335

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

base_tree = DecisionTreeClassifier(max_depth=1,class_weight='balanced')
ada_classifier = AdaBoostClassifier(estimator=base_tree)
ada_param_grid = {
    'n_estimators':[50,100,200],
    'learning_rate':[0.01,0.1,1,10]
}

ada_grid= GridSearchCV(ada_classifier, ada_param_grid)

# %%
ada_grid.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(class_weight='balanced',
#                                                                            max_depth=1)),
#              param_grid={'learning_rate': [0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
ada_pred = ada_grid.predict(scaled_X_test)
modelperformance(ada_pred)
# Out:
# Accuracy score is 0.3233333333333333

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()

xgb_param_grid = {
    'n_estimators':[20,40,60,80,100,500,1000,2000,5000],
    'learning_rate':[0.01,0.1,0.2,0.3,0.5,0.7,1],
    'max_depth': [1,3,4,5,7,9]
}

# %%
import sys
print(sys.executable)
# Out:
# d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Scripts\python.exe

# %%
xgb_grid= GridSearchCV(xgb, xgb_param_grid)

# %%
xgb_grid.fit(scaled_X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 xgb_grid.fit(scaled_X_train, y_train)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:866, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864         estimator.fit(X_train, **fit_params)
#     865     else:
# --> 866         estimator.fit(X_train, y_train, **fit_params)
#     868 except Exception:
#     869     # Note fit time as time until error
#     870     fit_time = time.time() - start_time
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\xgboost\sklearn.py:1682, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1660 model, metric, params, feature_weights = self._configure_fit(
#    1661     xgb_model, params, feature_weights
#    1662 )
#    1663 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1664     missing=self.missing,
#    1665     X=X,
#    (...)   1679     feature_types=self.feature_types,
#    1680 )
# -> 1682 self._Booster = train(
#    1683     params,
#    1684     train_dmatrix,
#    1685     self.get_num_boosting_rounds(),
#    1686     evals=evals,
#    1687     early_stopping_rounds=self.early_stopping_rounds,
#    1688     evals_result=evals_result,
#    1689     obj=obj,
#    1690     custom_metric=metric,
#    1691     verbose_eval=verbose,
#    1692     xgb_model=model,
#    1693     callbacks=self.callbacks,
#    1694 )
#    1696 if not callable(self.objective):
#    1697     self.objective = params["objective"]
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\xgboost\training.py:184, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     182         break
#     183     bst.update(dtrain, iteration=i, fobj=obj)
# --> 184     if cb_container.after_iteration(bst, i, dtrain, evals):
#     185         break
#     187 bst = cb_container.after_training(bst)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\xgboost\callback.py:264, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     262 for _, name in evals:
#     263     assert name.find("-") == -1, "Dataset name should not contain `-`"
# --> 264 score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     265 metric_score = _parse_eval_str(score)
#     266 self._update_history(metric_score, epoch)
#
# File d:\My Courses\Projects\Credit Card Approval Predictor\Credit-Card-Approval-Predictor\.venv\Lib\site-packages\xgboost\core.py:2353, in Booster.eval_set(self, evals, iteration, feval, output_margin)
#    2350 evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#    2351 msg = ctypes.c_char_p()
#    2352 _check_call(
# -> 2353     _LIB.XGBoosterEvalOneIter(
#    2354         self.handle,
#    2355         ctypes.c_int(iteration),
#    2356         dmats,
#    2357         evnames,
#    2358         c_bst_ulong(len(evals)),
#    2359         ctypes.byref(msg),
#    2360     )
#    2361 )
#    2362 assert msg.value is not None
#    2363 res = msg.value.decode()  # pylint: disable=no-member
#
# KeyboardInterrupt:

# %%
xgb_pred = xgb_grid.predict(scaled_X_test)
modelperformance(xgb_pred)

# %%
from joblib import dump
dump(ada_grid, 'ada_model.joblib')
# Out:
# ['ada_model.joblib']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ada_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[ 68 201]
#  [  2  29]]
